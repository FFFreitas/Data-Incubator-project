# %% [markdown]
# Chord plot showing the size and overlaping of the 14 different classes (diseases) generated from the metadat avalaible in Data_Entry_2017.csv

# %%
from IPython.display import Image 
Image(filename='chord_all_classes.png')

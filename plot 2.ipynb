# %% [markdown]
# One interesting plot is the activation map, this plot show the regions which activate more a respective class, this plot provides us an insight on what are the features that the CNN is learning.

# %%
from IPython.display import Image 
Image(filename='activation map.png')

# %% [markdown]
# and the respective grad cam:

# %%
from IPython.display import Image 
Image(filename='grad map.png')
